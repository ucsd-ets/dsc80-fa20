# %% [markdown]
# # DSC 80
# The Practice and Application of Data Science
#
# Fall 2020

# %% [markdown]
# ## Lecture Outline + Record the lecture
#
# * Introduction
# * Course overview
# * What's a "practicing data scientist"?
# * The "Data Science Workflow"

# %% [markdown]
# ## Introduction
#
# * Name: Marina Langlois
# * Pronouns: she/her
# * Graduated: UIC (PhD in Computer Science)
# * Past Experience: UIC, Yeshiva University, UCSD (CS department)
# * Finally here :)

# %% [markdown]
# # Course Information

# %% [markdown]
# ## Course Goals
#
# * Practice translating potentially vague questions into quantitative questions about measurable observations.
# * Learn to reason about 'black-box' processes (e.g. complicated models).
# * Understand computational and statistical implications of working with data.
# * Learn to use real data tools (e.g. love the documentation!).
# * Give a taste of the "life of a data scientist".

# %% [markdown]
# ## Course Outcomes
#
# * Prepare you for internships and data science "take home" interviews!
# * Enable you to create your own portfolio of personal projects (Project 3 and 5)
# * Prepare you for upper-division ML and Stats courses (material and maturity).

# %% [markdown]
# ## Course Materials and Information
#
# * The course [github repository](https://github.com/ucsd-ets/dsc80-fa20): assignments, lectures, references.
#     - https://https://github.com/ucsd-ets/dsc80-fa20
# * The course [website](https://sites.google.com/ucsd.edu/dsc80-spring-2020/): syllabus, links, schedule.
#     - https://sites.google.com/ucsd.edu/dsc-80-fall-2020
#
# All of this linked on Piazza.

# %% [markdown]
# ##  Course Components: Description
#
# |Component|Description|
# |---|---|
# |Labs |Practice with basic material|
# |Discussions|(Extra) Practice with basic material|
# |Projects|In-depth work on real problems|
# |First 5 weeks|Working with and reasoning about data|
# |Last 5 weeks|Creating and evaluating models|

# %% [markdown]
# ##  Course Components: Grade Breakdown
#
# |Component|Percentage|
# |---|---|
# |Labs (weekly)|20%|
# |Discussions/Checkpoints|5%|
# |Projects (5, bi-weekly)|30%|
# |Midterm (mid-quarter)|15%|
# |Final (cumulative)|30%|

# %% [markdown]
# ## Course Materials
#
# * We kinda-sorta have a book! (finally!)
#     - https://afraenkel.github.io/practical-data-science
#     - the lecture slides serve as sources of information and practice.
#
# * Just like a working Data Scientist:
#     - using new, evolving tools requires doing your own research!
#     - using real data require doing your own research!
#     - *You* will be responsible for assessing the correctness of your research!

# %% [markdown]
# ## Secondary references
#
# * Wes McKinney. "Python for Data Analysis" ([Link - requires UCSD internet](proquest.safaribooksonline.com/9781449323592))
# * Sam Lau, Joey Gonzalez, and Deb Nolan. "Principles and Techniques of Data Science" (https://www.textbook.ds100.org/)
# * Ani Adhikari and John DeNero. "Computational and Inferential Thinking" (https://www.inferentialthinking.com)
# * On-line tutorials are great, but be sure to understand the *concepts* in the lecture!

# %% [markdown]
# ## A few last remarks...
#
# * This course requires *a lot* of work; gaining fluency working with data is hard!
# * You will have to learn things on your own (e.g. love the documentation).
# * Learning to effectively check your work (and debug) pays dividends:
#     - Does my answer *look* right for the context?
#     - Does my code do what I think? (small data testing)
#     - Does my code generalize properly? (unseen data testing)

# %% [markdown]
# # Coding for DSC80
#
#
# * You will not be graded on style.
# * Some requirement are will be enforced.

# %% [markdown]
# ## Lectures
#
# * Pre-recorded and assigned for each lecture
# * Up you when to watch them but try not to fall behind
# * Some lectures will be longer than 50 min, some will be shorter.
# * Notebook will not line up with the videos
# * Can be found on the website for the first 2 weeks.
# * **Today**: record the rest after the intro lecture.

# %% [markdown]
# ## Exams
#
# * Format: To be decided

# %% [markdown]
# ## Questions?
#
# ### Personal Questions?

# %% [markdown]
# # What is a data scientist?
#
# <div class="image-txt-container">
#
# * [The Venn Diagram](http://drewconway.com/zia/2013/3/26/the-data-science-venn-diagram), Drew Conway, 2010
# * Statistics: drawing conclusions.
# * Hacking: extracting information.
# * Substantive Expertise: understanding context.
#
# <img src="imgs/image_0.png" width = 40%>
#
# </div>

# %% [markdown]
# # What is a data scientist?
#
# <div class="image-txt-container">
#
# * [Battle of the Data Science Venn Diagrams](http://www.prooffreader.com/2016/09/battle-of-data-science-venn-diagrams.html)
# * Stephan Kolassa, 2014
# * Data Science is expanding and maturing.
# * Find a niche you enjoy!
# * Understanding a little of everything is powerful.
#
# <img src="imgs/image_1.png" width = 50%>
#
# </div>

# %% [markdown]
# ## What is a data scientist?
#
# * Extracts usable information from data. (~CS)
# * Uses that information to answer questions. (~Stats)
# * Uses that information to solve problems. (~Science)
#
# Let's look at a few examples...

# %% [markdown]
# ## Predicting Elections
#
# <div class="image-txt-container">
#     <div></div>
#
# * What does the electorate look like?
# * What are the important traits?
# * How do we gather/measure those traits?
# * Quantify into a model / Draw conclusion with confidence!
#
# <img src="imgs/538.png" width="50%">
# </div>

# %% [markdown]
# ## Internet Advertisements
# Can using internet ads increase a dealership's truck sales?
#
# <div class="image-txt-container">
#     <div></div>
#
# * How likely is a person to click?
# * Who is it shown to?
# * How do ad clicks translate to sales?
# * Are they *causing* higher sales?
# * What data should I collect?
#
# <img src="imgs/internet_ads.gif" width="500">
# </div>

# %% [markdown]
# ## Image recognition for celebrity GIFs
#
# [Gfycat](https://www.wired.com/story/how-coders-are-fighting-bias-in-facial-recognition-software/) resolves celebrity faces to generate memes.
#
# <div class="image-txt-container">
# <img src="imgs/Chris.png" width="50%">
# <img src="imgs/Twice.png" width="50%">
# </div>

# %% [markdown]
# ## Data Science requires responsible practice
#
# <div class="image-txt-container">
#
# - Easy to obscure complex decisions made with data:
#     * 2009 market crash.
#     * Criminal sentencing.
#     * Hiring and Admissions.
#     * Hyper-personalized ad recommendations.
#
# <img src="imgs/image_2.png" width="50%">
#
# </div>

# %% [markdown]
# ## Data Science requires responsible practice
#
# <div class="image-txt-container">
#
# * Reinforcing historical trends and biases:
#     - Hiring based on previous hiring data.
#     - Criminal sentencing using previous decisions.
#     - Social media, news, and politics
#
# * Data is generated by people; treat people responsibly!
#
#
# <img src="imgs/image_2.png" width="50%">
#
# </div>

# %% [markdown]
# # The Data Science Lifecycle

# %% [markdown]
# ## The scientific method hides complexity
#
# <div class="image-txt-container">
#
# * From what context did your hypothesis come?
# * What data are you using/measuring?
#     - What if the data isn't sufficient?
# * Under which conditions are the conclusions valid?
# * The language of modeling helps answer these questions.
#
# <img src="imgs/image_3.png">
#
# </div>

# %% [markdown]
# ## Introduction to models
#
# * A **data generating process** is the real-world phenomenon under consideration.
# * The **true (probability) model** is a mathematical representation of random phenomenon that generates any representative observations (you can reason about it probabilistically).
# * The **observations** are data representing the data generating process.
# * A **(fit) statistical model** of the data is the best approximation of the data generating process under the probability model.

# %% [markdown]
# ### The Data Science Life-cycle: Everything leads to more questions!
# <img src="imgs/DSLC.png" width="40%">

# %% [markdown]
# ### Research Domain
#
# <div class="image-txt-container">
#     <div></div>
#
# * What subject do we care about?
# * How is relevant data generated?
#
# <img src="imgs/DSLC.png">
# </div>

# %% [markdown]
# ### Question or Hypothesis
#
# <div class="image-txt-container">
#     <div></div>
#
# * What do we want to know?
# * What problem are we trying to solve?
# * What are our metrics for success?
# * Hypotheses are refined from any stage of work!
#
# <img src="imgs/DSLC.png">
# </div>

# %% [markdown]
# ### Find and Clean Data
#
# <div class="image-txt-container">
#     <div></div>
#
# * What data exists and can it answer the question?
# * Do we need to collect/measure our own data?
# * Cleaning the data: does it well-represent the domain?
#
# <img src="imgs/DSLC.png">
# </div>

# %% [markdown]
# ### Data Modeling
#
# <div class="image-txt-container">
#     <div></div>
#
# * What assumptions are made of data to draw conclusions?
# * What biases or anomalies exist in the data?
# * How is the data simplified to use for predictions and inference?
#
# <img src="imgs/DSLC.png">
# </div>

# %% [markdown]
# ### Predictions and Inference
#
# <div class="image-txt-container">
#     <div></div>
#
# * What does the data say about the world?
# * Does it answer our questions? Solve our problem?
# * Can we trust our conclusions and predictions?
#
# <img src="imgs/DSLC.png">
# </div>

# %% [markdown]
# # Example: SD Employee Salaries

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import util

# %% [markdown]
# ## Example: SD Employee Salaries
#
# * Build a "profile" of city of SD employees?
# * Which jobs make more/less? How much?
# * Who works part-time? full-time?
# * Are salaries "fair"?

# %% [markdown]
# ### SD Employee Salaries: background research
#
# * Why try to understand this dataset?
#     - Such a profile could inform 3rd party workplace programs.
#     - Journalists might search for salary anomalies.
#     - Auditors may want actionable advice on fair employment practices.

# %% [markdown]
# ### Initial look at the data
# * [Transparent California](https://transparentcalifornia.com/salaries/san-diego/) salary website.

# %%
salary_path = util.safe_download('https://transcal.s3.amazonaws.com/public/export/san-diego-2017.csv')

# %%
salaries = pd.read_csv(salary_path)
salaries
# Out:
#                   Employee Name                           Job Title  Base Pay  \
# 0               David P Gerboth                Fire Battalion Chief   81917.0
# 1              Glen A Bartolome                        Fire Captain   85904.0
# 2              Scott C Chadwick             Chief Operating Officer  255000.0
# 3             David W Pilkerton                Fire Battalion Chief  100110.0
# 4               Daniel S Reeves                        Fire Captain   41389.0
# 5                Edward S Jones                        Fire Captain   46020.0
# 6             Richard L Ballard                Fire Battalion Chief   99629.0
# 7                  Mark A Hovey            Retirement Administrator  240000.0
# 8             Adrian A Blackson                        Fire Captain   44280.0
# 9             Stacey D Lomedico                Asst Chief Oper Ofcr  215000.0
# 10               Eric B Dunnick                       Fire Engineer   31869.0
# 11               Hadi  Dehghani                  Personnel Director  207210.0
# 12              Harold A Lemire                        Fire Captain   59413.0
# Total Pay             12493.0  64984.971024  41812.990357     3.0  36430.0
# Total Pay & Benefits  12493.0  73652.726007  45761.462637     3.0  44788.0
# Year                  12493.0   2017.000000      0.000000  2017.0   2017.0
# Notes                     0.0           NaN           NaN     NaN      NaN
#
#                           50%       75%       max
# Base Pay              49254.0   68952.0  255000.0
# Overtime Pay            393.0    5408.0  196978.0
# Benefits               8420.0   13485.0   36030.0
# Total Pay             61452.0   91400.0  323377.0
# Total Pay & Benefits  71264.0  103131.0  328571.0
# Year                   2017.0    2017.0    2017.0
# Notes                     NaN       NaN       NaN

# %% [markdown]
# * Negative payments? Near zero salaries?
# * Where is "Other Pay"?
# * Max values -- are outliers real?

# %% [markdown]
# ### Empirical Distribution of Salaries
# * Bimodal (two distributions?)
# * Typical skew: Pay > 0

# %%
salaries['Total Pay'].plot(kind='hist', bins=50, density=True);

# %% [markdown]
# ### Empirical Distribution of Salaries
# * Part-time vs full-time

# %%
bystatus = salaries.groupby('Status')
bystatus['Total Pay'].plot(kind='kde', alpha=0.5, title='Salary by Full-time/Part-time')
plt.legend(bystatus.groups);

# %% [markdown]
# ### Do women earn similar pay to their contemporaries?
# * Do employees of different genders have similar pay?
# * Don't have gender information in our salary data.
#     - Do have (first) names of employees!
#     - Join to Social Security Administration "baby names" dataset!

# %%
names_path = util.safe_download('https://www.ssa.gov/oact/babynames/names.zip')

# %%
from glob import glob
import os

filelist = glob(os.path.join(names_path, '*.txt'))
df_list = [pd.read_csv(f, names=['firstname', 'gender', 'count']).assign(year=f[-8:-4]) for f in filelist]

names = pd.concat(df_list)
names.head()
# Out:
#    firstname gender  count  year
# 0       Mary      F   7065  1880
# 1       Anna      F   2604  1880
# 2       Emma      F   2003  1880
# 3  Elizabeth      F   1939  1880
# 4     Minnie      F   1746  1880

# %% [markdown]
# ### SSA names dataset
# * Contains the list of names on social security applications
# * For each name, it contains:
#     - the number of applications per year identified as Male/Female
# * We want a list of names and most likely gender to join to `salaries`.

# %% [markdown]
# ### Basic check of `names`:
# * Many names identify to both genders.
# * Most names occur only a few times per year.
# * A few names occur very often.

# %%
# glance at data
names.head()
# Out:
#    firstname gender  count  year
# 0       Mary      F   7065  1880
# 1       Anna      F   2604  1880
# 2       Emma      F   2003  1880
# 3  Elizabeth      F   1939  1880
# 4     Minnie      F   1746  1880

# %%
# look at a single name
names[names['firstname'] == 'Madison']
# Out:
#       firstname gender  count  year
# 1311    Madison      M     22  1880
# 1248    Madison      M     28  1881
# 1369    Madison      M     27  1882
# 1419    Madison      M     22  1883
# 1580    Madison      M     20  1884
# 1602    Madison      M     20  1885
# 1725    Madison      M     17  1886
# 1705    Madison      M     18  1887
# 1883    Madison      M     21  1888
# 1853    Madison      M     23  1889
# 2057    Madison      M     14  1890
# 1924    Madison      M     20  1891
# 2096    Madison      M     20  1892
# 2246    Madison      M     12  1893
# 2318    Madison      M     12  1894
# 2353    Madison      M     15  1895
# 2402    Madison      M     14  1896
# 2402    Madison      M     13  1897
# 2412    Madison      M     13  1899
# 2837    Madison      M     17  1900
# 2850    Madison      M      7  1901
# 3030    Madison      M      7  1902
# 2596    Madison      M     18  1903
# 2912    Madison      M     11  1904
# 2922    Madison      M     13  1905
# 2885    Madison      M     14  1906
# 2977    Madison      M     19  1907
# 3294    Madison      M     11  1908
# 3675    Madison      M      8  1909
# 3597    Madison      M     15  1910
# ...         ...    ...    ...   ...
# 2       Madison      F  20622  2004
# 19685   Madison      M    207  2004
# 2       Madison      F  19568  2005
# 20865   Madison      M     80  2005
# 2       Madison      F  18626  2006
# 22051   Madison      M     67  2006
# 4       Madison      F  17961  2007
# 22592   Madison      M     69  2007
# 5       Madison      F  17032  2008
# 22775   Madison      M     57  2008
# 6       Madison      F  15239  2009
# 22518   Madison      M     56  2009
# 7       Madison      F  13183  2010
# 23092   Madison      M     34  2010
# 7       Madison      F  12389  2011
# 22091   Madison      M     49  2011
# 8       Madison      F  11397  2012
# 22999   Madison      M     31  2012
# 8       Madison      F  10596  2013
# 22113   Madison      M     40  2013
# 8       Madison      F  10320  2014
# 22104   Madison      M     40  2014
# 10      Madison      F  10088  2015
# 21055   Madison      M     74  2015
# 14      Madison      F   9030  2016
# 21695   Madison      M     42  2016
# 16      Madison      F   7875  2017
# 21468   Madison      M     38  2017
# 21      Madison      F   7036  2018
# 21219   Madison      M     36  2018
#
# [178 rows x 4 columns]

# %%
# look at statistics of counts

# count: number of people associated to a name in a given year

names.describe()
# Out:
#               count
# count  1.957046e+06
# mean   1.796856e+02
# std    1.522804e+03
# min    5.000000e+00
# 25%    7.000000e+00
# 50%    1.200000e+01
# 75%    3.200000e+01
# max    9.968900e+04

# %% [markdown]
# ### Approach:
# * Create a data frame of distinct names with the proportion of applications on which that name identifies as female.
# * That is, for each name $N$, we compute:
#
# $$P({\rm person\ is\ female\ }|{\rm \ person\ has\ first\ name\ } N)$$
#
# * Join this data frame to the salaries dataset

# %% [markdown]
# ### Calculate names and their most likely genders

# %%
# Counts by gender

cnts_by_gender = names.groupby(['firstname', 'gender']).sum().reset_index().pivot('firstname', 'gender', 'count').fillna(0)
cnts_by_gender
# Out:
# gender            F       M
# firstname
# Aaban           0.0   114.0
# Aabha          35.0     0.0
# Aabid           0.0    16.0
# Aabidah         5.0     0.0
# Aabir           0.0    10.0
# Aabriella      38.0     0.0
# Aada           13.0     0.0
# Aadam           0.0   273.0
# Aadan           0.0   130.0
# Aadarsh         0.0   209.0
# Aadaya          8.0     0.0
# Aaden           5.0  4828.0
# Aadesh          0.0    22.0
# Aadhav          0.0   217.0
# Aadhavan        0.0    44.0
# Aadhi           0.0    54.0
# Aadhira       107.0     0.0
# Aadhiran        0.0     6.0
# Aadhvik         0.0    54.0
# Aadhvika       17.0     0.0
# Aadhya       1725.0     0.0
# Aadhyan         0.0    18.0
# Aadhyareddy     6.0     0.0
# Aadhyasri       6.0     0.0
# Aadi           16.0   851.0
# Aadian          0.0     5.0
# Aadil           0.0   361.0
# Aadilynn        5.0     0.0
# Aadin           0.0   124.0
# Aadish          0.0    37.0
# ...             ...     ...
# Zyria         371.0     0.0
# Zyriah        419.0     0.0
# Zyrian          0.0    10.0
# Zyriana        30.0     0.0
# Zyrianna       41.0     0.0
# Zyrie          19.0    16.0
# Zyriel         16.0     0.0
# Zyrielle       27.0     0.0
# Zyrihanna      45.0     0.0
# Zyrin           0.0    10.0
# Zyrion          0.0   101.0
# Zyriyah        16.0     0.0
# Zyron           0.0   208.0
# Zyrus           0.0    77.0
# Zysean          0.0     5.0
# Zyshaun         0.0    34.0
# Zyshawn         0.0   146.0
# Zyshon          0.0    19.0
# Zyshonne        0.0   101.0
# Zytaevius       0.0     5.0
# Zytaveon        0.0    17.0
# Zytavion        0.0     5.0
# Zytavious       0.0    43.0
# Zyus            0.0    11.0
# Zyva           23.0     0.0
# Zyvion          0.0     5.0
# Zyvon           0.0     7.0
# Zyyanna         6.0     0.0
# Zyyon           0.0     6.0
# Zzyzx           0.0    10.0
#
# [98400 rows x 2 columns]

# %%
# proportion of a given name that's identified female
prop_female = (cnts_by_gender['F'] / cnts_by_gender.sum(axis=1))
prop_female.head(10)
# Out:
# firstname
# Aaban        0.0
# Aabha        1.0
# Aabid        0.0
# Aabidah      1.0
# Aabir        0.0
# Aabriella    1.0
# Aada         1.0
# Aadam        0.0
# Aadan        0.0
# Aadarsh      0.0
# dtype: float64

# %%
genders = prop_female.rename('prop_female').to_frame().assign(gender=np.where((prop_female > 0.5), 'F', 'M'))
genders
# Out:
#              prop_female gender
# firstname
# Aaban           0.000000      M
# Aabha           1.000000      F
# Aabid           0.000000      M
# Aabidah         1.000000      F
# Aabir           0.000000      M
# Aabriella       1.000000      F
# Aada            1.000000      F
# Aadam           0.000000      M
# Aadan           0.000000      M
# Aadarsh         0.000000      M
# Aadaya          1.000000      F
# Aaden           0.001035      M
# Aadesh          0.000000      M
# Aadhav          0.000000      M
# Aadhavan        0.000000      M
# Aadhi           0.000000      M
# Aadhira         1.000000      F
# Aadhiran        0.000000      M
# Aadhvik         0.000000      M
# Aadhvika        1.000000      F
# Aadhya          1.000000      F
# Aadhyan         0.000000      M
# Aadhyareddy     1.000000      F
# Aadhyasri       1.000000      F
# Aadi            0.018454      M
# Aadian          0.000000      M
# Aadil           0.000000      M
# Aadilynn        1.000000      F
# Aadin           0.000000      M
# Aadish          0.000000      M
# ...                  ...    ...
# Zyria           1.000000      F
# Zyriah          1.000000      F
# Zyrian          0.000000      M
# Zyriana         1.000000      F
# Zyrianna        1.000000      F
# Zyrie           0.542857      F
# Zyriel          1.000000      F
# Zyrielle        1.000000      F
# Zyrihanna       1.000000      F
# Zyrin           0.000000      M
# Zyrion          0.000000      M
# Zyriyah         1.000000      F
# Zyron           0.000000      M
# Zyrus           0.000000      M
# Zysean          0.000000      M
# Zyshaun         0.000000      M
# Zyshawn         0.000000      M
# Zyshon          0.000000      M
# Zyshonne        0.000000      M
# Zytaevius       0.000000      M
# Zytaveon        0.000000      M
# Zytavion        0.000000      M
# Zytavious       0.000000      M
# Zyus            0.000000      M
# Zyva            1.000000      F
# Zyvion          0.000000      M
# Zyvon           0.000000      M
# Zyyanna         1.000000      F
# Zyyon           0.000000      M
# Zzyzx           0.000000      M
#
# [98400 rows x 2 columns]

# %% [markdown]
# ### Add a given name column to `salaries` and join names

# %%
# Add firstname column
salaries['firstname'] = salaries['Employee Name'].str.split().apply(lambda x:x[0])
salaries
# Out:
#                   Employee Name                           Job Title  Base Pay  \
# 0               David P Gerboth                Fire Battalion Chief   81917.0
# 1              Glen A Bartolome                        Fire Captain   85904.0
# 2              Scott C Chadwick             Chief Operating Officer  255000.0
# 3             David W Pilkerton                Fire Battalion Chief  100110.0
# 4               Daniel S Reeves                        Fire Captain   41389.0
# 5                Edward S Jones                        Fire Captain   46020.0
# 6             Richard L Ballard                Fire Battalion Chief   99629.0
# 7                  Mark A Hovey            Retirement Administrator  240000.0
# 8             Adrian A Blackson                        Fire Captain   44280.0
# 9             Stacey D Lomedico                Asst Chief Oper Ofcr  215000.0
# 10               Eric B Dunnick                       Fire Engineer   31869.0
# 11               Hadi  Dehghani                  Personnel Director  207210.0
# 12              Harold A Lemire                        Fire Captain   59413.0
# 13                  John O Wood                        Fire Captain   74753.0
# 14              Andrea H Tevlin           Independent Budget Anlyst  224099.0
# 15             Alan J Arrollado                Fire Battalion Chief  100041.0
# 16               Jason L Hewitt                        Fire Captain   51094.0
# 17              Gary F Mondesir                      Police Officer   92206.0
# 18            Korry D Belmontez                        Fire Captain   48699.0
# 19                 Mary J Lewis             Chief Financial Officer  180923.0
# 20               Ronald H Villa              Deputy Chief Oper Ofcr  195000.0
# 21                Halla H Razak           Public Utilities Director  163731.0
# 22              Paul C Alvernaz                        Fire Captain   52274.0
# 23                Aide F Barbat                Fire Battalion Chief   67117.0
# 24               Ty  Shimoguchi                Fire Battalion Chief   99773.0
# 25          Elizabeth A Crisafi                  Investment Officer  206932.0
# 26              Jesse G Schultz                        Fire Captain   52616.0
# 27             Brian P Fennessy                          Fire Chief  180000.0
# 28                Dennis R Clay                Fire Battalion Chief   78058.0
# 29          Michael A De Guzman                        Fire Captain   85904.0
# ...                         ...                                 ...       ...
# 12463            Martin D Lykke                        Library Aide     162.0
# 12464            Isaiah N Higgs                            Rec Aide     161.0
# 12465        Elizabeth R Guzman                        Library Aide     150.0
# 12466     Gina E Nourmohamadian                      Fire Fighter 1       0.0
# 12467  Ezequiel  Ramirez Wojcik                        Pool Guard 1     144.0
# 12468   Alondra  Zacarias Lopez                            Rec Aide     138.0
# 12469         Aleena J Houseman  Special Event Traffic Controller 1     126.0
# 12470             Joy L Freeman                     Deputy Director       0.0
# 12471           Annelia M Black                        Rec Leader 1     114.0
# 12472            Reyna C Moreno                     Clerical Asst 2       0.0
# 12473           Yvonne  Edwards  Special Event Traffic Controller 1     106.0
# 12474             Mark A Stroud                      Police Officer       0.0
# 12475          Kevin C Kinnamon                        Rec Leader 1      43.0
# 12476          Rebecca M Cesena                Word Processing Oper       0.0
# 12477  Christopher L Shropshire                        Rec Leader 1      58.0
# 12478          Vanessa M Wright                  Marine Biologist 2       0.0
# 12479            Wesley J Hamik                      Fire Fighter 2       0.0
# 12473  2017    NaN  San Diego     PT       Yvonne
# 12474  2017    NaN  San Diego     PT         Mark
# 12475  2017    NaN  San Diego     PT        Kevin
# 12476  2017    NaN  San Diego     PT      Rebecca
# 12477  2017    NaN  San Diego     PT  Christopher
# 12478  2017    NaN  San Diego     PT      Vanessa
# 12479  2017    NaN  San Diego     PT       Wesley
# 12480  2017    NaN  San Diego     PT        Kevin
# 12481  2017    NaN  San Diego     PT       Andrew
# 12482  2017    NaN  San Diego     PT        Micah
# 12483  2017    NaN  San Diego     PT       Joshua
# 12484  2017    NaN  San Diego     PT      Alberto
# 12485  2017    NaN  San Diego     PT       Edward
# 12486  2017    NaN  San Diego     PT         Lisa
# 12487  2017    NaN  San Diego     PT      Jasmine
# 12488  2017    NaN  San Diego     PT      Michael
# 12489  2017    NaN  San Diego     PT      Mohamad
# 12490  2017    NaN  San Diego     PT      Stephen
# 12491  2017    NaN  San Diego     PT        Tania
# 12492  2017    NaN  San Diego     PT        Brian
#
# [12493 rows x 13 columns]

# %%
# join gender
salaries_with_gender = salaries.merge(genders, on='firstname', how='left')
salaries_with_gender.head()
# Out:
#        Employee Name                Job Title  Base Pay  Overtime Pay  \
# 0    David P Gerboth     Fire Battalion Chief   81917.0      172590.0
# 1   Glen A Bartolome             Fire Captain   85904.0      120682.0
# 2   Scott C Chadwick  Chief Operating Officer  255000.0           0.0
# 3  David W Pilkerton     Fire Battalion Chief  100110.0      118798.0
# 4    Daniel S Reeves             Fire Captain   41389.0      196284.0
#
#   Other Pay  Benefits  Total Pay  Total Pay & Benefits  Year  Notes  \
# 0  68870.00    5194.0   323377.0              328571.0  2017    NaN
# 1  99408.00   10107.0   305994.0              316101.0  2017    NaN
# 2  31164.00   22688.0   286164.0              308852.0  2017    NaN
# 3  62895.00   18746.0   281803.0              300549.0  2017    NaN
# 4  42027.00   20125.0   279700.0              299825.0  2017    NaN
#
#       Agency Status firstname  prop_female gender
# 0  San Diego     FT     David     0.003552      M
# 1  San Diego     FT      Glen     0.010651      M
# 2  San Diego     FT     Scott     0.003371      M
# 3  San Diego     FT     David     0.003552      M
# 4  San Diego     PT    Daniel     0.004246      M

# %% [markdown]
# ### Do women earn similar pay to their contemporaries?
# * Is this difference significant, or just noise?

# %%
pd.concat([
    salaries_with_gender.groupby('gender')['Total Pay'].describe().T,
    salaries_with_gender['Total Pay'].describe().rename('All')
], axis=1)
# Out:
#                    F              M            All
# count    4153.000000    7895.000000   12493.000000
# mean    53946.543703   71239.687017   64984.971024
# std     36254.857386   43430.325681   41812.990357
# min         8.000000       3.000000       3.000000
# 25%     25853.000000   41583.000000   36430.000000
# 50%     50787.000000   67920.000000   61452.000000
# 75%     75127.000000  100729.000000   91400.000000
# max    237512.000000  323377.000000  323377.000000

# %% [markdown]
# ### Use a hypothesis test
# * Can women's median pay be explained as a random subset of the population of city of SD salaries?
#     - If so, the salary of women doesn't significantly differ from the population
#     - If not, some other mechanism is needed to explain the difference!

# %%
# size of sample is number of women:
n_female = (salaries_with_gender['gender'] == 'F').sum()


# calculate observed 
female_median = salaries_with_gender.loc[salaries_with_gender['gender'] == 'F']['Total Pay'].median()


# simulate 1000 draws from the population of size n_female
medians = []
for _ in np.arange(1000):
    median = salaries_with_gender.sample(n_female)['Total Pay'].median()
    medians.append(median)

# %%
title='Median salary of randomly chosen groups from population'
pd.Series(medians).plot(kind='hist', title=title);
plt.plot([female_median], [0], marker='o', markersize=10)
plt.legend(['Observed Median Salary of Women', 'Median Salaries of Random Groups']);

# %% [markdown]
# ## Truism of data science
#
# * Answering one question always raises 10 more.

# %% [markdown]
# ### Questions:
#
# * Can we trust the SD employee population?
# * Can we trust the name-to-gender assignment?
# * Can we trust our join?
# * Is the disparity correlated to pay-type? job status? job type?
# * What is the cause of the disparity?

# %% [markdown]
# ### Can we trust the SD employee population?
#
# * Look up the "transparent california" and verify this dataset is a *census* (everyone).
# * Is "Total Pay" the most appropriate field to use?
# * Cross-reference independent counts of city of SD employees to assess the salary data.

# %% [markdown]
# ### Can we trust the name-to-gender assignment?
# * How many names are borderline male/female?
# * Does it make sense we incorporate name usage from 1880-2017?

# %%
title = 'distribution of gendered-ness of names\n 0 = masculine \n 1 = feminine'
prop_female.plot(kind='hist', bins=20, title=title);

# %% [markdown]
# * However, each unit plotted is a distinct name; the proportions hide the number of people with each name.
# * What if the most popular name in the country is gender-neutral?

# %% [markdown]
# ### Can we trust our join?
# * Are there names in the salary dataset that aren't in the SSA dataset?
#     - Who might not be in the SSA dataset?
#     - Might they be biased toward certain salaries?
# * Does the salary dataset have a disproportionately large portion of unisex names.
# * Is it better to use a subset of the SSA dataset (e.g. by state?)
#     - Do the gender of names typically vary by geography?

# %% [markdown]
# ### Can we trust our join?

# %%
# proportion of employees not in SSA dataset
salaries_with_gender['gender'].isnull().mean()

# %%
# Description of total pay by joined vs not joined
(
    salaries_with_gender
    .assign(joined=salaries_with_gender['gender'].notnull())
    .groupby('joined')['Total Pay']
    .describe()
    .T
)

# %%
nonjoins = salaries_with_gender.loc[salaries_with_gender['gender'].isnull()]

title = 'Distribution of Salaries'
nonjoins['Total Pay'].plot(kind='hist', bins=50, alpha=0.5, density=True, sharex=True)
salaries_with_gender['Total Pay'].plot(kind='hist', bins=50, alpha=0.5, density=True, sharex=True, title=title)
plt.legend(['Not in SSA','All']);

# %% [markdown]
# ### Can we trust our join?
# * Lesson: joining to another dataset can bias your sample!

# %% [markdown]
# ### Is the pay disparity correlated to another field? job status? job type?
# * Is the proportion of women in a job type correlated to pay?
#     - Controlling for job type, do women earn similar salaries?

# %%
# select jobs with word 'fire' in them
firejobs = salaries_with_gender.loc[salaries_with_gender['Job Title'].str.contains('Fire')]
firejobs.head()
# Out:
#        Employee Name             Job Title  Base Pay  Overtime Pay Other Pay  \
# 0    David P Gerboth  Fire Battalion Chief   81917.0      172590.0  68870.00
# 1   Glen A Bartolome          Fire Captain   85904.0      120682.0  99408.00
# 3  David W Pilkerton  Fire Battalion Chief  100110.0      118798.0  62895.00
# 4    Daniel S Reeves          Fire Captain   41389.0      196284.0  42027.00
# 5     Edward S Jones          Fire Captain   46020.0      171896.0  59944.00
#
#    Benefits  Total Pay  Total Pay & Benefits  Year  Notes     Agency Status  \
# 0    5194.0   323377.0              328571.0  2017    NaN  San Diego     FT
# 1   10107.0   305994.0              316101.0  2017    NaN  San Diego     FT
# 3   18746.0   281803.0              300549.0  2017    NaN  San Diego     FT
# 4   20125.0   279700.0              299825.0  2017    NaN  San Diego     PT
# 5   19669.0   277860.0              297529.0  2017    NaN  San Diego     PT
#
#   firstname  prop_female gender
# 0     David     0.003552      M
# 1      Glen     0.010651      M
# 3     David     0.003552      M
# 4    Daniel     0.004246      M
# 5    Edward     0.004136      M

# %%
# Proportion of fire-related jobs held by women
(firejobs['gender'] == 'F').mean()
# Out:
# 0.08849557522123894

# %%
# Pay Statistics for fire-related jobs
firejobs['Total Pay'].describe()
# Out:
# count      1017.000000
# mean     110967.646018
# std       49678.113970
# min          57.000000
# 25%       81319.000000
# 50%      112568.000000
# 75%      141502.000000
# max      323377.000000
# Name: Total Pay, dtype: float64

# %%
# select jobs with library related jobs
libjobs = salaries_with_gender.loc[salaries_with_gender['Job Title'].str.contains('Librar')]
libjobs.head()
# Out:
#                 Employee Name           Job Title  Base Pay  Overtime Pay  \
# 334             Misty N Jones      City Librarian  155000.0           0.0
# 1355           Robert M Cronk  Deputy Library Dir  112000.0           0.0
# 1399  Sheila R Tucker-Burnett  Deputy Library Dir  112000.0           0.0
# 2693         Ramiro  Gonzalez      Supv Librarian   84864.0           0.0
# 3010             Kelly J Pepo      Supv Librarian   82081.0           0.0
#
#      Other Pay  Benefits  Total Pay  Total Pay & Benefits  Year  Notes  \
# 334   12269.00       0.0   167269.0              167269.0  2017    NaN
# 1355   4121.00   15944.0   116121.0              132065.0  2017    NaN
# 1399   5074.00   14202.0   117074.0              131276.0  2017    NaN
# 2693  11079.00   12968.0    95943.0              108911.0  2017    NaN
# 3010   9000.00   13603.0    91081.0              104684.0  2017    NaN
#
#          Agency Status firstname  prop_female gender
# 334   San Diego     FT     Misty     0.997201      F
# 1355  San Diego     FT    Robert     0.004152      M
# 1399  San Diego     FT    Sheila     0.997285      F
# 2693  San Diego     FT    Ramiro     0.001137      M
# 3010  San Diego     FT     Kelly     0.852388      F

# %%
# Proportion of library-related jobs held by women
(libjobs['gender'] == 'F').mean()
# Out:
# 0.642089093701997

# %%
# Pay Statistics for fire-related jobs
libjobs['Total Pay'].describe()
# Out:
# count       651.000000
# mean      30383.377880
# std       23236.318495
# min          23.000000
# 25%       10598.500000
# 50%       26952.000000
# 75%       43566.000000
# max      167269.000000
# Name: Total Pay, dtype: float64

# %% [markdown]
# ### What is the cause of the disparity?
# * Now that the picture is better understood, you can:
#     - Research historical gender preferences across jobs
#     - list possibilities and formulate hypothesis for a cause,
#     - find data capable of describing these possibilities,
#     - use a [natural experiment](https://en.wikipedia.org/wiki/Natural_experiment) to argue causality.

# %% [markdown]
# ### Possible follow-ups
# * Clean job titles to reflect broader job categories.
# * Further investigate correlation between job categories and gender proportions.
# * Do the analogous investigation with age in place of gender.
